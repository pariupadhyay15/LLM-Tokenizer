# %% [markdown]
# <a href="https://colab.research.google.com/github/pariupadhyay15/LLM-Tokenizer/blob/main/LLM_Tokenizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("the-verdict.txt", "r", encoding='utf-8') as f:
  raw_text= f.read()
print("Total number of character:", len(raw_text))
# Out:
# Total number of character: 20479

# %%
import re
preprocessed = re.split(r'([,.]|\s)', raw_text)
preprocessed= [item for item in preprocessed if item.strip()]

# %%
print(len(preprocessed))
# Out:
# 4092

# %%
all_words= sorted(set(preprocessed))
print(len(all_words))
# Out:
# 1317

# %%
vocab= {token:integer for integer, token in enumerate(all_words)}

# %%
class SimpleTokenizerV1:
  def __init__(self, vocab):
    self.str_to_int= vocab
    self.int_to_str= {i:s for s,i in vocab.items()}
  def encode(self, text):
    preprocessed = re.split(r'([,.:;?_!"()\]|--|\s)', text)
    preprocessed=[
        item.strip() for item in preprocessed if item.strip()
    ]
    ids= [self.str_to_int[s] for s in preprocessed]
    return ids
  def decode(self, ids):
    text=" ".join([self.int_to_str[i] for i in ids])
    text= re.sub(r'\s+([,.?!"()\'])', r'\1', text)
    return text

# %%
import re

class SimpleTokenizerV1:
  def __init__(self, vocab):
    self.str_to_int= vocab
    self.int_to_str= {i:s for s,i in vocab.items()}

  def encode(self, text):  #it converts the text given to it into token ids using the vocab dict
    preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)
    preprocessed=[
        item.strip() for item in preprocessed if item.strip()
    ]
    ids= [self.str_to_int[s] for s in preprocessed]
    return ids


  def decode(self, ids): # it turn back the ids into words
    text=" ".join([self.int_to_str[i] for i in ids])
    text= re.sub(r'\s+([,.?!"()\'])', r'\1', text)
    return text

# %%
tokenizer= SimpleTokenizerV1(vocab)

text=""" the last he painted, you know,"
        . Gisburn said with pardonable pride."""
ids = tokenizer.encode(text)
print(ids)
# Out:
# [1152, 725, 629, 894, 65, 1309, 718, 65, 0, 66, 90, 1011, 1287, 907, 953, 66]

# %%
tokenizer.decode(ids)
# Out:
# 'the last he painted, you know,". Gisburn said with pardonable pride.'

# %%
all_tokens=sorted(list(set(preprocessed)))
all_tokens.extend(["<|endoftext|>","<|unk|>"])

vocab={token:integer for integer, token in enumerate(all_tokens)}

# %%
len(vocab.items())
# Out:
# 1319

# %%
class SimpleTokenizerV2:
  def __init__(self, vocab):
    self.str_to_int= vocab
    self.int_to_str= {i:s for s,i in vocab.items()}
  def encode(self, text):  #it converts the text given to it into token ids using the vocab dict
    preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)', text)
    preprocessed=[
        item.strip() for item in preprocessed if item.strip()
    ]
    preprocessed=[
        item if item in self.str_to_int
        else "<|unk|>" for item in preprocessed
    ]
    ids= [self.str_to_int[s] for s in preprocessed]
    return ids
  def decode(self, ids): # it turn back the ids into words
    text=" ".join([self.int_to_str[i] for i in ids])
    text= re.sub(r'\s+([,.?!"()\'])', r'\1', text)
    return text

# %%
tokenizer1= SimpleTokenizerV2(vocab)

text=""" mrs.the last he painted, you know,"
        . Gisburn said with pardonable pride."""
ids = tokenizer1.encode(text)
print(ids)
# Out:
# [1318, 66, 1152, 725, 629, 894, 65, 1309, 718, 65, 0, 66, 90, 1011, 1287, 907, 953, 66]

# %%
tokenizer1.decode(ids)
# Out:
# '<|unk|>. the last he painted, you know,". Gisburn said with pardonable pride.'
